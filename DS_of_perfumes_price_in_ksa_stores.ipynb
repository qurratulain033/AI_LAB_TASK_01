# %% [markdown]
# <a href="https://colab.research.google.com/github/qurratulain033/AI_LAB_TASK_01/blob/main/DS_of_perfumes_price_in_ksa_stores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d mouathalmansour/perfumes-price-in-ksa-stores
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mouathalmansour/perfumes-price-in-ksa-stores
# License(s): apache-2.0
# ...
# 100% 1.79M/1.79M [00:00<00:00, 2.49MB/s]
# 100% 1.79M/1.79M [00:00<00:00, 2.21MB/s]

# %%
# !unzip perfumes-price-in-ksa-stores
# Out:
# Archive:  perfumes-price-in-ksa-stores.zip
#   inflating: perfumesdata.csv

# %%
import pandas as pd
df = pd.read_csv('perfumesdata.csv')
df
# Out:
#        Unnamed: 0                                       product_link  \
# 0               0  https://saudi.ibrahimalqurashi.com/ar/%D8%A7%D...
# 1               1  https://saudi.ibrahimalqurashi.com/ar/%D8%A7%D...
# 2               2  https://saudi.ibrahimalqurashi.com/ar/%D8%B3%D...
# 3               3  https://saudi.ibrahimalqurashi.com/ar/%D8%A7%D...
# 4               4  https://saudi.ibrahimalqurashi.com/ar/%D8%AA%D...
# ...           ...                                                ...
# 25024        1704  https://najdalatheyah.com/%D9%84%D9%8A%D9%84-%...
# 25025        1705  https://najdalatheyah.com/%D8%B9%D8%B7%D8%B1-%...
# 25026        1706  https://najdalatheyah.com/%D8%B9%D8%B7%D8%B1-%...
# 25027        1707  https://najdalatheyah.com/%D8%B9%D8%B7%D8%B1-%...
# 25028        1708  https://najdalatheyah.com/%D8%B9%D8%B7%D8%B1-%...
#
#                                           extracted_link info1  \
# 0      https://cdn.salla.sa/rAoegy/9HX8xa8NpOsPRW3IpK...   50%
# ...

# %%
print(df.head(2))  # Display first 10 rows.
# Out:
#    Unnamed: 0                                       product_link  \
# 0           0  https://saudi.ibrahimalqurashi.com/ar/%D8%A7%D...
# 1           1  https://saudi.ibrahimalqurashi.com/ar/%D8%A7%D...
#
#                                       extracted_link info1  \
# 0  https://cdn.salla.sa/rAoegy/9HX8xa8NpOsPRW3IpK...   50%
# 1  https://cdn.salla.sa/rAoegy/zhOZ4Em75fC2uqBeSV...   50%
#
#               product_name discounted_price product_price        info2  \
# 0    اريبيان توباكو 200 مل          220 ر.س       440 ر.س  إضافة للسلة
# 1  التوباكو الفرنسي 200 مل          199 ر.س       398 ر.س  إضافة للسلة
#
#   product_description      store_name extracted_date product_category gender
# 0                 NaN  ابراهيم القرشي     2024-09-03         perfumes    NaN
# 1                 NaN  ابراهيم القرشي     2024-09-03         perfumes    NaN
