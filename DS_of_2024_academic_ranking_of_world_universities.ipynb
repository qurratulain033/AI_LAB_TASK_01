# %% [markdown]
# <a href="https://colab.research.google.com/github/qurratulain033/AI_LAB_TASK_01/blob/main/DS_of_2024_academic_ranking_of_world_universities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d computingvictor/2024-academic-ranking-of-world-universities
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/computingvictor/2024-academic-ranking-of-world-universities
# License(s): apache-2.0
# ...
#   0% 0.00/19.5k [00:00<?, ?B/s]
# 100% 19.5k/19.5k [00:00<00:00, 37.3MB/s]

# %%
# !unzip 2024-academic-ranking-of-world-universities
# Out:
# Archive:  2024-academic-ranking-of-world-universities.zip
#   inflating: shanghai_ranking_2024.csv

# %%
import pandas as pd
df = pd.read_csv('shanghai_ranking_2024.csv')
df
# Out:
#          Rank                              University_Name  \
# 0           1                           Harvard University
# 1           2                          Stanford University
# 2           3  Massachusetts Institute of Technology (MIT)
# 3           4                      University of Cambridge
# 4           5           University of California, Berkeley
# ..        ...                                          ...
# 995  901-1000                     Universidad Andrés Bello
# 996  901-1000                         University of Lahore
# 997  901-1000                          Linnaeus University
# 998  901-1000                      University of Wuppertal
# 999  901-1000            Abdul Wali Khan University Mardan
#
#     National/Regional Rank  Alumni  Award   Hici    N&S    PUB   PCP
# 0                        1   100.0   97.1  100.0  100.0  100.0  85.7
# 1                        2    45.3   88.1   73.1   83.9   73.1  59.6
# ...
