# %% [markdown]
# <a href="https://colab.research.google.com/github/qurratulain033/AI_LAB_TASK_01/blob/main/DS_of_amazon_cell_phones_cleaned_scraped_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d michaelmatta0/amazon-cell-phones-cleaned-scraped-data
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/michaelmatta0/amazon-cell-phones-cleaned-scraped-data
# License(s): MIT
# ...
#   0% 0.00/1.55M [00:00<?, ?B/s]
# 100% 1.55M/1.55M [00:00<00:00, 126MB/s]

# %%
# !unzip amazon-cell-phones-cleaned-scraped-data
# Out:
# Archive:  amazon-cell-phones-cleaned-scraped-data.zip
#   inflating: Amazon_Cell_Phones.csv
#   inflating: Raw_Data_Before_Cleaning.csv

# %%
import pandas as pd
df = pd.read_csv('Amazon_Cell_Phones.csv')
df
# Out:
#         ID                                       product_name  \
# 0        1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 1        2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 2        3  Apple iPhone 12, 64GB, Black - Fully Unlocked ...
# 3        4  OnePlus Nord CE 2,​ 5G Unlocked Android Smartp...
# 4        5  Apple iPhone XS, US Version, 64GB, Space Gray ...
# ...    ...                                                ...
# 3346  3347  iP13 Pro Unlocked Smartphones, for Android 6 C...
# 3347  3348  realme 11 5G Dual SIM 8+256GB | RMX3780 |108MP...
# 3348  3349  realme C67 | Android 14 | Unlocked | Dual SIM ...
# 3349  3350  unlocked phone，E66，Android smartphone ，Interna...
# 3350  3351  unlocked phone，Reno5Pro+，Android smartphone ，I...
#
#                                            product_link  \
# 0     https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 1     https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# ...
