# %% [markdown]
# <a href="https://colab.research.google.com/github/qurratulain033/AI_LAB_TASK_01/blob/main/DS_of_health_and_sleep_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d hanaksoy/health-and-sleep-statistics
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/hanaksoy/health-and-sleep-statistics
# License(s): CC0-1.0
# ...
#   0% 0.00/1.17k [00:00<?, ?B/s]
# 100% 1.17k/1.17k [00:00<00:00, 2.67MB/s]

# %%
# !unzip health-and-sleep-statistics
# Out:
# Archive:  health-and-sleep-statistics.zip
#   inflating: Health_Sleep_Statistics.csv

# %%
import pandas as pd
df = pd.read_csv('Health_Sleep_Statistics.csv')
df
# Out:
#     User ID  Age Gender  Sleep Quality Bedtime Wake-up Time  Daily Steps  \
# 0         1   25      f              8   23:00        06:30         8000
# 1         2   34      m              7   00:30        07:00         5000
# 2         3   29      f              9   22:45        06:45         9000
# 3         4   41      m              5   01:00        06:30         4000
# 4         5   22      f              8   23:30        07:00        10000
# ..      ...  ...    ...            ...     ...          ...          ...
# 95       96   43      m              7   00:45        07:15         6500
# 96       97   33      f              8   23:15        06:15         8500
# 97       98   46      m              4   01:30        07:00         3000
# 98       99   25      f              9   22:15        06:45         9500
# 99      100   41      m              6   00:30        07:00         5000
#
#     Calories Burned Physical Activity Level Dietary Habits Sleep Disorders  \
# ...
